# %% [markdown]
# # Load the data

# %%
import os
import huggingface_hub
import matplotlib.pyplot as plt
from dotenv import load_dotenv
from datasets import load_dataset

# %%
load_dotenv()
huggingface_hub.login(os.getenv("HF_TOKEN"))
dataset = load_dataset("nhhsag12/vlsp_2025_multimodal_rag")
dataset
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'image_id', 'question', 'relevant_articles', 'question_type', 'choices', 'answer', 'image'],
#         num_rows: 530
#     })
# })

# %%
data_train = dataset["train"]
print(len(data_train))
# Out:
# 530

# %% [markdown]
# # Analyze the current dataset

# %% [markdown]
# ## Question type

# %%
question_types = set()
for data in data_train:
    question_types.add(data["question_type"])
print(question_types)
# Out:
# {'Multiple choice', 'Yes/No'}

# %%
multiple_choice_count = 0
yes_no_count = 0
for data in data_train:
    if data["question_type"] == "Multiple choice":
        multiple_choice_count += 1
    else:
        yes_no_count += 1
print(f"Number of Multiple choice questions: {multiple_choice_count}")
print(f"Number of Yes/No questions: {yes_no_count}")
# Out:
# Number of Multiple choice questions: 376
# Number of Yes/No questions: 154

# %% [markdown]
# ## Relevant articles analysis

# %% [markdown]
# ### Convert the string representation of list into list data type in relevant articles field

# %%
from copy import deepcopy
import ast
processed_data_train = []
for idx, data in enumerate(data_train):
    new_record = deepcopy(data)

    # Convert the string representation of the list of the dictionary elements to the list type
    new_record["relevant_articles"] = ast.literal_eval(new_record["relevant_articles"])

    processed_data_train.append(new_record)

# %% [markdown]
# ### Analysis

# %%
max_relevant_articles = 0
min_relevant_articles = 999

for data in processed_data_train:
    max_relevant_articles = max(max_relevant_articles, len(data["relevant_articles"]))
    min_relevant_articles = min(min_relevant_articles, len(data["relevant_articles"]))

print(f"Max number of relevant articles: {max_relevant_articles}")
print(f"Min number of relevant articles: {min_relevant_articles}")
# Out:
# Max number of relevant articles: 8
# Min number of relevant articles: 1

# %%
article_counts = [0 for _ in range(max_relevant_articles + 1)]
for data in processed_data_train:
    article_counts[len(data["relevant_articles"])] += 1

for i in range(1, 9):
    print(f"Number of articles with {i} relevant articles: {article_counts[i]}")
# Out:
# Number of articles with 1 relevant articles: 78
# Number of articles with 2 relevant articles: 337
# Number of articles with 3 relevant articles: 39
# Number of articles with 4 relevant articles: 48
# Number of articles with 5 relevant articles: 11
# Number of articles with 6 relevant articles: 14
# Number of articles with 7 relevant articles: 1
# Number of articles with 8 relevant articles: 2

# %%
for data in processed_data_train:
    if len(data["relevant_articles"]) == 7:
        print(data)
        break
# Out:
# {'id': 'train_399', 'image_id': 'train_6_31', 'question': 'Từ 6:00 đến 22:00, tất cả các loại xe (cơ giới và thô sơ) không được phép rẽ vào đường Hồng Hà trên đoạn đường trong ảnh, đúng hay sai?', 'relevant_articles': [{'law_id': 'QCVN 41:2024/BGTVT', 'article_id': '22'}, {'law_id': 'QCVN 41:2024/BGTVT', 'article_id': 'B.23'}, {'law_id': 'QCVN 41:2024/BGTVT', 'article_id': '36'}, {'law_id': 'QCVN 41:2024/BGTVT', 'article_id': 'E.14'}, {'law_id': 'QCVN 41:2024/BGTVT', 'article_id': '41'}, {'law_id': 'QCVN 41:2024/BGTVT', 'article_id': 'F.5'}, {'law_id': 'QCVN 41:2024/BGTVT', 'article_id': 'F.10'}], 'question_type': 'Yes/No', 'choices': None, 'answer': 'Sai', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=465x406 at 0x7489C90E7A70>}

# %% [markdown]
# ## Number of words in questions

# %%
import torch
from transformers import AutoProcessor, AutoModel, BitsAndBytesConfig, AutoTokenizer

bnb_config = BitsAndBytesConfig(load_in_4bit=True)
model = AutoModel.from_pretrained("google/siglip2-large-patch16-512",
                                  quantization_config=bnb_config,
                                  device_map="auto",
                                  attn_implementation="sdpa")
processor = AutoProcessor.from_pretrained("google/siglip2-base-patch16-224")
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File /usr/lib/python3.12/importlib/metadata/__init__.py:397, in Distribution.from_name(cls, name)
#     396 try:
# --> 397     return next(cls.discover(name=name))
#     398 except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# PackageNotFoundError                      Traceback (most recent call last)
# Cell In[6], line 4
#       1 import torch
#       2 from transformers import AutoProcessor, AutoModel, BitsAndBytesConfig, AutoTokenizer
# ----> 4 bnb_config = BitsAndBytesConfig(load_in_4bit=True)
#       5 model = AutoModel.from_pretrained("google/siglip2-large-patch16-512",
#       6                                   quantization_config=bnb_config,
#       7                                   device_map="auto",
#       8                                   attn_implementation="sdpa")
#       9 processor = AutoProcessor.from_pretrained("google/siglip2-base-patch16-224")
#
# File ~/Documents/Multimodal Machine Learning/VLSP_2025/vlsp_2025_multimodal_rag/.venv/lib/python3.12/site-packages/transformers/utils/quantization_config.py:508, in BitsAndBytesConfig.__init__(self, load_in_8bit, load_in_4bit, llm_int8_threshold, llm_int8_skip_modules, llm_int8_enable_fp32_cpu_offload, llm_int8_has_fp16_weight, bnb_4bit_compute_dtype, bnb_4bit_quant_type, bnb_4bit_use_double_quant, bnb_4bit_quant_storage, **kwargs)
#     505 if kwargs:
#     506     logger.info(f"Unused kwargs: {list(kwargs.keys())}. These kwargs are not used in {self.__class__}.")
# --> 508 self.post_init()
#
# File ~/Documents/Multimodal Machine Learning/VLSP_2025/vlsp_2025_multimodal_rag/.venv/lib/python3.12/site-packages/transformers/utils/quantization_config.py:566, in BitsAndBytesConfig.post_init(self)
#     563 if not isinstance(self.bnb_4bit_use_double_quant, bool):
#     564     raise TypeError("bnb_4bit_use_double_quant must be a boolean")
# --> 566 if self.load_in_4bit and not version.parse(importlib.metadata.version("bitsandbytes")) >= version.parse(
#     567     "0.39.0"
#     568 ):
#     569     raise ValueError(
#     570         "4 bit quantization requires bitsandbytes>=0.39.0 - please upgrade your bitsandbytes version"
#     571     )
#
# File /usr/lib/python3.12/importlib/metadata/__init__.py:889, in version(distribution_name)
#     882 def version(distribution_name):
#     883     """Get the version string for the named package.
#     884
#     885     :param distribution_name: The name of the distribution package to query.
#     886     :return: The version string for the package as defined in the package's
#     887         "Version" metadata key.
#     888     """
# --> 889     return distribution(distribution_name).version
#
# File /usr/lib/python3.12/importlib/metadata/__init__.py:862, in distribution(distribution_name)
#     856 def distribution(distribution_name):
#     857     """Get the ``Distribution`` instance for the named package.
#     858
#     859     :param distribution_name: The name of the distribution package as a string.
#     860     :return: A ``Distribution`` instance (or subclass thereof).
#     861     """
# --> 862     return Distribution.from_name(distribution_name)
#
# File /usr/lib/python3.12/importlib/metadata/__init__.py:399, in Distribution.from_name(cls, name)
#     397     return next(cls.discover(name=name))
#     398 except StopIteration:
# --> 399     raise PackageNotFoundError(name)
#
# PackageNotFoundError: No package metadata was found for bitsandbytes

# %% [markdown]
# # Analyze the current database

# %%
import json

db_path = "../data/VLSP 2025 - MLQA-TSR Data Release/law_db/vlsp2025_law.json"
with open(db_path, "r") as f:
    db = json.load(f)

print(f"Number of records: {len(db)}")
# Out:
# Number of records: 2

# %%
for record in db:
    print(f"Record ID: {record['id']}")
    print(f"Law title: {record['title']}")
    print(f"Number of articles: {len(record['articles'])}")
    print("-"*10)
# Out:
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Number of articles: 310
# ----------
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Number of articles: 89
# ----------

# %%
min_image_cnt = 999
max_image_cnt = 0

def count_image_tags(text):
    """
    Counts the occurrences of the <<IMAGE: ..../IMAGE>> format in a given text.

    Args:
        text: The input string to search within.

    Returns:
        The number of times the image tag format appears in the text.
    """
    # The regular expression to match the image tag format
    # <<IMAGE: any_characters_non_greedy /IMAGE>>
    pattern = r"<<IMAGE:.*?/IMAGE>>"

    # Find all occurrences of the pattern
    matches = re.findall(pattern, text)

    # Return the number of matches
    return len(matches)


for record in db:
    for article in record["articles"]:
        image_num = count_image_tags(article["text"])
        min_image_cnt = min(min_image_cnt, image_num)
        max_image_cnt = max(max_image_cnt, image_num)
        print(f"Record ID: {record['id']}")
        print(f"Law title: {record['title']}")
        print(f"Article ID: {article['id']}")
        # print(f"Number of articles: {len(record['articles'])}")
        print(f"Number of images: {image_num}")

print(f"Maximum number of images in a article: {max_image_cnt}")
print(f"Minimum number of images in a article: {min_image_cnt}")
# Out:
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 1
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 2
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 3
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 4
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 5
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 6
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 7
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 8
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 9
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 10
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 11
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 12
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 13
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 14
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 15
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 16
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 17
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 18
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 19
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 20
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 21
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 22
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 23
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 24
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 25
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 26
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 27
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 28
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 29
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 30
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 31
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 32
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 33
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 34
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 35
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 36
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 37
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 38
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 39
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 40
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 41
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 42
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 43
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 44
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 45
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 46
# Number of images: 6
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 47
# Number of images: 30
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 48
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 49
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 50
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 51
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 52
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 53
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 54
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 55
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 56
# Number of images: 3
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 57
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 58
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 59
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 60
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 61
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 62
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 63
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 64
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 65
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 66
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 67
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 68
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 69
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 70
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 71
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 72
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 73
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 74
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 75
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 76
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 77
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 78
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 79
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 80
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 81
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 82
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 83
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: 84
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: A.1
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: A.2
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.1
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.2
# Number of images: 2
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.4
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.5
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.6
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.7
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.7a
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.7b
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.8
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.8a
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.9
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.10
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.11
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.12
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.13
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.14
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.15
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.16
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.17
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.18
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.19
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.20
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.21
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.23
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.24
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.25
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.26
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.27
# Number of images: 2
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.27a
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.27b
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.27c
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.27d
# Number of images: 2
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.28
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.29
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.30
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.31
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.32
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.33
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.34
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.35
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.36
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.37
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.38
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.39
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: B.40
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.1
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.1a
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.2
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.3
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.4
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.5
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.6
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.7
# Number of images: 3
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.8
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.9
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.10
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.11
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.12
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.13
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.14
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.15
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.16
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.17
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.18
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.19
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.20
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.21
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.22
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.23
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.24
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.25
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.26
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.27
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.28
# Number of images: 2
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.29
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.30
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.31
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.32
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.33
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.34
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.35
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.36
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.37
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.38
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.39
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.40
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.41
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.42
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.43
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.44
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.45
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.46
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: C.47
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.1
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.1a
# Number of images: 2
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.2
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.3
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.4
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.5
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.6
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.7
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.8
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.9
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.10
# Number of images: 2
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.12
# Number of images: 2
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.13
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.14
# Number of images: 2
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.15
# Number of images: 2
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.16
# Number of images: 2
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.17
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.18
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.19
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.20
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: D.21
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.1
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.2
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.5
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.6
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.7
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.8
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.8a
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.9
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.10
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.13
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.14
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.15
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.16
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.17
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.18
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.19
# Number of images: 2
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.22
# Number of images: 2
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.23a
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.23b
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.24
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.25
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.26
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.27
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.28
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.29
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.30
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.31
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.32
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.33
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.34
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.35a
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.35b
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.35c
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.36
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.37
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.38
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.39
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.40
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.42
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.43
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.44
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.45
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.46
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.47
# Number of images: 4
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.48
# Number of images: 3
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.49
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.50
# Number of images: 2
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.51
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: E.52
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: F.1
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: F.2
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: F.3
# Number of images: 3
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: F.4
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: F.5
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: F.6
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: F.7
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: F.8
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: F.9
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: F.10
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: F.11
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: F.12
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: F.13
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: F.14
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: F.15
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: F.16
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: F.17
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: G.1
# Number of images: 48
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: G.2
# Number of images: 36
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: I.1
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: I.2
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: I.3
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: I.4
# Number of images: 7
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: K.1
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: K.1
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: K.1
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: K.2
# Number of images: 0
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: K.2
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: K.2
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: M.1
# Number of images: 64
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: M.2
# Number of images: 83
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: M.3
# Number of images: 74
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: M.4
# Number of images: 111
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: N
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: O
# Number of images: 12
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.1
# Number of images: 2
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.2
# Number of images: 2
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.3
# Number of images: 3
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.4
# Number of images: 3
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.5
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.6
# Number of images: 3
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.7
# Number of images: 7
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.8
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.9
# Number of images: 11
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.10
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.11
# Number of images: 3
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.12
# Number of images: 4
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.13
# Number of images: 10
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.14
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.15
# Number of images: 3
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.16
# Number of images: 3
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.17
# Number of images: 2
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.18
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.19
# Number of images: 3
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.20
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.21
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.22
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.23
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.24
# Number of images: 5
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.25
# Number of images: 1
# Record ID: QCVN 41:2024/BGTVT
# Law title: QUY CHUẨN KỸ THUẬT QUỐC GIA VỀ BÁO HIỆU ĐƯỜNG BỘ
# Article ID: P.26
# Number of images: 1
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 1
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 2
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 3
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 4
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 5
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 6
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 7
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 8
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 9
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 10
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 11
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 12
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 13
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 14
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 15
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 16
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 17
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 18
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 19
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 20
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 21
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 22
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 23
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 24
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 25
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 26
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 27
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 28
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 29
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 30
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 31
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 32
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 33
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 34
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 35
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 36
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 37
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 38
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 39
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 40
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 41
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 42
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 43
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 44
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 45
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 46
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 47
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 48
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 49
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 50
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 51
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 52
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 53
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 54
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 55
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 56
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 57
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 58
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 59
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 60
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 61
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 62
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 63
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 64
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 65
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 66
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 67
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 68
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 69
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 70
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 71
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 72
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 73
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 74
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 75
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 76
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 77
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 78
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 79
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 80
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 81
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 82
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 83
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 84
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 85
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 86
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 87
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 88
# Number of images: 0
# Record ID: 36/2024/QH15
# Law title: LUẬT TRẬT TỰ, AN TOÀN GIAO THÔNG ĐƯỜNG BỘ
# Article ID: 89
# Number of images: 0
# Maximum number of images in a article: 111
# Minimum number of images in a article: 0

# %%
txt = ""

for record in db[0]["articles"]:
    if record["id"] == "M.4":
        txt = record["text"]
        print(txt)
        break
# Out:
# Biển số I.401: Bắt đầu đường ưu tiên
#
# <<IMAGE: image1132.jpg /IMAGE>>
# Biển số I.402: Hết đoạn đường ưu tiên
#
# <<IMAGE: image1134.jpg /IMAGE>>
# Biển số I.405a: Đường cụt
#
# <<IMAGE: image1136.jpg /IMAGE>>
# <<TABLE: <table border="0" cellpadding="0" cellspacing="0" class="MsoNormalTable" style="width:100.0%;border-collapse:collapse;mso-padding-alt:0cm 0cm 0cm 0cm" width="100%">
# <tr style="mso-yfti-irow:0;mso-yfti-firstrow:yes">
# <td style="width:25.7%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Lo</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ại
#   đường</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:25.32%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ôi
#   ngoài đô th</span><span lang="VI" style="color:black;mso-color-alt:windowtext;
#   mso-ansi-language:VI">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.96%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   th</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ông
#   thư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;
#   mso-ansi-language:VI">ờng</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.02%;border:solid black 1.0pt;border-bottom:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-right-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ô th</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# <tr style="mso-yfti-irow:1;mso-yfti-lastrow:yes">
# <td style="width:25.7%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">z(mm)</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:25.32%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">100</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.96%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">75</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.02%;border:solid black 1.0pt;mso-border-alt:
#   solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">50</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# </table> /TABLE>>
# Biển số I.405b: Đường cụt
#
# <<IMAGE: image1138.jpg /IMAGE>>
# Biển số I.405c: Đường cụt
#
# <<IMAGE: image1140.jpg /IMAGE>>
# Biển số I.406: Được ưu tiên qua đường hẹp
#
# <<IMAGE: image1142.jpg /IMAGE>>
# <<TABLE: <table border="0" cellpadding="0" cellspacing="0" class="MsoNormalTable" style="width:100.0%;border-collapse:collapse;mso-padding-alt:0cm 0cm 0cm 0cm" width="100%">
# <tr style="mso-yfti-irow:0;mso-yfti-firstrow:yes">
# <td style="width:25.7%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Lo</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ại
#   đường</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:25.32%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ôi
#   ngoài đô th</span><span lang="VI" style="color:black;mso-color-alt:windowtext;
#   mso-ansi-language:VI">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.96%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   th</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ông thư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.02%;border:solid black 1.0pt;border-bottom:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-right-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ô th</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# <tr style="mso-yfti-irow:1;mso-yfti-lastrow:yes">
# <td style="width:25.7%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">z(mm)</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:25.32%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">100</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.96%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">75</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.02%;border:solid black 1.0pt;mso-border-alt:
#   solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">50</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# </table> /TABLE>>
# Biển số I.407a: Đường một chiều
#
# <<IMAGE: image1144.jpg /IMAGE>>
# Biển số I.407b: Đường một chiều
#
# <<IMAGE: image1146.jpg /IMAGE>>
# Biển số I.407c: Đường một chiều
#
# <<IMAGE: image1148.jpg /IMAGE>>
# <<TABLE: <table border="0" cellpadding="0" cellspacing="0" class="MsoNormalTable" style="width:100.0%;border-collapse:collapse;mso-padding-alt:0cm 0cm 0cm 0cm" width="100%">
# <tr style="mso-yfti-irow:0;mso-yfti-firstrow:yes">
# <td style="width:25.7%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Lo</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ại
#   đường</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:25.32%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ôi
#   ngoài đô th</span><span lang="VI" style="color:black;mso-color-alt:windowtext;
#   mso-ansi-language:VI">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.96%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   th</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ông
#   thư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;
#   mso-ansi-language:VI">ờng</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.02%;border:solid black 1.0pt;border-bottom:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-right-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ô th</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# <tr style="mso-yfti-irow:1;mso-yfti-lastrow:yes">
# <td style="width:25.7%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">z(mm)</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:25.32%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">100</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.96%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">75</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.02%;border:solid black 1.0pt;mso-border-alt:
#   solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">50</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# </table> /TABLE>>
# Biển số I.408: Nơi đỗ xe
#
# <<IMAGE: image1150.jpg /IMAGE>>
# Biển số I.408a: Nơi đỗ xe một phần trên hè phố
#
# <<IMAGE: image1152.jpg /IMAGE>>
# Biển số I.409: Chỗ quay xe
#
# <<IMAGE: image1154.jpg /IMAGE>>
# <<TABLE: <table border="0" cellpadding="0" cellspacing="0" class="MsoNormalTable" style="width:100.0%;border-collapse:collapse;mso-padding-alt:0cm 0cm 0cm 0cm" width="100%">
# <tr style="mso-yfti-irow:0;mso-yfti-firstrow:yes">
# <td style="width:25.7%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Lo</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ại
#   đường</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:25.32%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ôi
#   ngoài đô th</span><span lang="VI" style="color:black;mso-color-alt:windowtext;
#   mso-ansi-language:VI">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.96%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   th</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ông
#   thư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;
#   mso-ansi-language:VI">ờng</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.02%;border:solid black 1.0pt;border-bottom:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-right-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ô th</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# <tr style="mso-yfti-irow:1;mso-yfti-lastrow:yes">
# <td style="width:25.7%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">z(mm)</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:25.32%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">100</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.96%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">75</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.02%;border:solid black 1.0pt;mso-border-alt:
#   solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">50</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# </table> /TABLE>>
# Biển số I.410: Khu vực quay xe
#
# <<IMAGE: image1156.jpg /IMAGE>>
# Biển số I.413a: Đường có làn đường dành cho ôtô khách
#
# <<IMAGE: image1158.jpg /IMAGE>>
# Biển số I.413b: Rẽ ra đường có làn đường dành cho ôtô khách
#
# <<IMAGE: image1160.jpg /IMAGE>>
# <<TABLE: <table border="0" cellpadding="0" cellspacing="0" class="MsoNormalTable" style="width:100.0%;border-collapse:collapse;mso-padding-alt:0cm 0cm 0cm 0cm" width="100%">
# <tr style="mso-yfti-irow:0;mso-yfti-firstrow:yes">
# <td style="width:25.7%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Lo</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ại
#   đường</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:25.32%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ôi
#   ngoài đô th</span><span lang="VI" style="color:black;mso-color-alt:windowtext;
#   mso-ansi-language:VI">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.96%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   th</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ông
#   thư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;
#   mso-ansi-language:VI">ờng</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.02%;border:solid black 1.0pt;border-bottom:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-right-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ô th</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# <tr style="mso-yfti-irow:1;mso-yfti-lastrow:yes">
# <td style="width:25.7%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">z(mm)</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:25.32%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">100</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.96%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">75</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.02%;border:solid black 1.0pt;mso-border-alt:
#   solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">50</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# </table> /TABLE>>
# Biển số I.413c: Rẽ ra đường có làn đường dành cho ôtô khách
#
# <<IMAGE: image1162.jpg /IMAGE>>
# Biển số I.414a: Chỉ hướng đường
#
# <<IMAGE: image1164.jpg /IMAGE>>
# Biển số I.414b: Chỉ hướng đường
#
# <<IMAGE: image1166.jpg /IMAGE>>
# <<TABLE: <table border="0" cellpadding="0" cellspacing="0" class="MsoNormalTable" style="width:100.0%;border-collapse:collapse;mso-padding-alt:0cm 0cm 0cm 0cm" width="100%">
# <tr style="mso-yfti-irow:0;mso-yfti-firstrow:yes">
# <td style="width:25.7%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Lo</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ại
#   đường</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:25.32%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ôi
#   ngoài đô th</span><span lang="VI" style="color:black;mso-color-alt:windowtext;
#   mso-ansi-language:VI">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.96%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   th</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ông
#   thư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;
#   mso-ansi-language:VI">ờng</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.02%;border:solid black 1.0pt;border-bottom:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-right-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ô th</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# <tr style="mso-yfti-irow:1;mso-yfti-lastrow:yes">
# <td style="width:25.7%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">z(mm)</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:25.32%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">100</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.96%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">75</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.02%;border:solid black 1.0pt;mso-border-alt:
#   solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">50</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# </table> /TABLE>>
# Biển số I.414c: Chỉ hướng đường
#
# <<IMAGE: image1168.jpg /IMAGE>>
# Biển số I.414d: Chỉ hướng đường
#
# <<IMAGE: image1170.jpg /IMAGE>>
# Biển số I.415: Mũi tên chỉ hướng đi
#
# <<IMAGE: image1172.jpg /IMAGE>>
#
# <<TABLE: <table border="0" cellpadding="0" cellspacing="0" class="MsoNormalTable" style="width:100.0%;border-collapse:collapse;mso-padding-alt:0cm 0cm 0cm 0cm" width="100%">
# <tr style="mso-yfti-irow:0;mso-yfti-firstrow:yes">
# <td style="width:25.7%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Lo</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ại
#   đường</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:25.32%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ôi
#   ngoài đô th</span><span lang="VI" style="color:black;mso-color-alt:windowtext;
#   mso-ansi-language:VI">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.96%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   th</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ông
#   thư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;
#   mso-ansi-language:VI">ờng</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.02%;border:solid black 1.0pt;border-bottom:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-right-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ô th</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# <tr style="mso-yfti-irow:1;mso-yfti-lastrow:yes">
# <td style="width:25.7%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">z(mm)</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:25.32%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">100</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.96%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">75</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.02%;border:solid black 1.0pt;mso-border-alt:
#   solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">50</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# </table> /TABLE>>
# Biển số I.416: Đường tránh
#
# <<IMAGE: image1174.jpg /IMAGE>>
# <<TABLE: <table border="0" cellpadding="0" cellspacing="0" class="MsoNormalTable" style="width:100.0%;border-collapse:collapse;mso-padding-alt:0cm 0cm 0cm 0cm" width="100%">
# <tr style="mso-yfti-irow:0;mso-yfti-firstrow:yes">
# <td style="width:25.7%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Lo</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ại
#   đường</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:25.32%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ôi
#   ngoài đô th</span><span lang="VI" style="color:black;mso-color-alt:windowtext;
#   mso-ansi-language:VI">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.96%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   th</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ông
#   thư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;
#   mso-ansi-language:VI">ờng</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.02%;border:solid black 1.0pt;border-bottom:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-right-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ô th</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# <tr style="mso-yfti-irow:1;mso-yfti-lastrow:yes">
# <td style="width:25.7%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">z(mm)</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:25.32%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">140</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.96%;border:solid black 1.0pt;border-right:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
#   mso-border-bottom-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">105</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.02%;border:solid black 1.0pt;mso-border-alt:
#   solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">70</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# </table> /TABLE>>
# Biển số I.417a: Chỉ hướng đường phải đi cho từng loại xe
#
# <<IMAGE: image1176.jpg /IMAGE>>
# Biển số I.417b: Chỉ hướng đường phải đi cho từng loại xe
#
# <<IMAGE: image1178.jpg /IMAGE>>
# Biển số I.417c: Chỉ hướng đường phải đi cho từng loại xe
#
# <<IMAGE: image1180.jpg /IMAGE>>
#
# <<TABLE: <table border="0" cellpadding="0" cellspacing="0" class="MsoNormalTable" style="width:100.0%;border-collapse:collapse;mso-padding-alt:0cm 0cm 0cm 0cm" width="100%">
# <tr style="mso-yfti-irow:0;mso-yfti-firstrow:yes">
# <td style="width:25.7%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Lo</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ại
#   đường</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:25.32%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="25%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ôi
#   ngoài đô th</span><span lang="VI" style="color:black;mso-color-alt:windowtext;
#   mso-ansi-language:VI">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.96%;border-top:solid black 1.0pt;border-left:
#   solid black 1.0pt;border-bottom:none;border-right:none;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;background:white;
#   padding:0cm 0cm 0cm 0cm" width="24%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-color-alt:windowtext;mso-ansi-language:EN">Đư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;mso-ansi-language:VI">ờng
#   th</span><span lang="EN-US" style="color:black;mso-color-alt:windowtext">ông
#   thư</span><span lang="VI" style="color:black;mso-color-alt:windowtext;
#   mso-ansi-language:VI">ờng</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:24.02%;border:solid black 1.0pt;border-bottom:
#   none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
# ...
# </td>
# <td style="width:30.1%;border:solid black 1.0pt;border-left:none;
#   mso-border-left-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="30%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">Đư</span><span lang="VI" style="color:black;mso-ansi-language:VI;mso-bidi-font-weight:bold">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-bidi-font-weight:bold">ôi
#   ngoài đô th</span><span lang="VI" style="color:black;mso-ansi-language:VI;
#   mso-bidi-font-weight:bold">ị</span><span lang="EN" style="mso-ansi-language:
#   EN"><o:p></o:p></span></p>
# </td>
# <td style="width:27.78%;border:solid black 1.0pt;border-left:
#   none;mso-border-left-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="27%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">Đư</span><span lang="VI" style="color:black;mso-ansi-language:VI;mso-bidi-font-weight:bold">ờng
#   th</span><span lang="EN-US" style="color:black;mso-bidi-font-weight:bold">ông
#   thư</span><span lang="VI" style="color:black;mso-ansi-language:VI;mso-bidi-font-weight:
#   bold">ờng</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:22.22%;border:solid black 1.0pt;border-left:
#   none;mso-border-left-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="22%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">Đư</span><span lang="VI" style="color:black;mso-ansi-language:VI;mso-bidi-font-weight:bold">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-bidi-font-weight:bold">ô th</span><span lang="VI" style="color:black;mso-ansi-language:VI;mso-bidi-font-weight:bold">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# <tr style="mso-yfti-irow:1;mso-yfti-lastrow:yes">
# <td style="width:19.9%;border:solid black 1.0pt;border-top:none;
#   mso-border-top-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="19%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">z(mm)</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:30.1%;border-top:none;border-left:none;
#   border-bottom:solid black 1.0pt;border-right:solid black 1.0pt;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="30%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">90</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:27.78%;border-top:none;border-left:none;
#   border-bottom:solid black 1.0pt;border-right:solid black 1.0pt;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="27%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">62,5</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:22.22%;border-top:none;border-left:none;
#   border-bottom:solid black 1.0pt;border-right:solid black 1.0pt;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="22%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">50</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# </table> /TABLE>>
#
# <<IMAGE: image1348.jpg /IMAGE>>
#
# <<IMAGE: image1350.jpg /IMAGE>>
# <<TABLE: <table border="0" cellpadding="0" cellspacing="0" class="MsoNormalTable" style="width:100.0%;border-collapse:collapse;mso-padding-alt:0cm 0cm 0cm 0cm" width="100%">
# <tr style="mso-yfti-irow:0;mso-yfti-firstrow:yes">
# <td style="width:19.9%;border:solid black 1.0pt;mso-border-alt:
#   solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="19%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">Lo</span><span lang="VI" style="color:black;mso-ansi-language:VI;mso-bidi-font-weight:bold">ại
#   đường</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:30.1%;border:solid black 1.0pt;border-left:none;
#   mso-border-left-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="30%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">Đư</span><span lang="VI" style="color:black;mso-ansi-language:VI;mso-bidi-font-weight:bold">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-bidi-font-weight:bold">ôi
#   ngoài đô th</span><span lang="VI" style="color:black;mso-ansi-language:VI;
#   mso-bidi-font-weight:bold">ị</span><span lang="EN" style="mso-ansi-language:
#   EN"><o:p></o:p></span></p>
# </td>
# <td style="width:27.78%;border:solid black 1.0pt;border-left:
#   none;mso-border-left-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="27%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">Đư</span><span lang="VI" style="color:black;mso-ansi-language:VI;mso-bidi-font-weight:bold">ờng
#   th</span><span lang="EN-US" style="color:black;mso-bidi-font-weight:bold">ông
#   thư</span><span lang="VI" style="color:black;mso-ansi-language:VI;mso-bidi-font-weight:
#   bold">ờng</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:22.22%;border:solid black 1.0pt;border-left:
#   none;mso-border-left-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="22%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">Đư</span><span lang="VI" style="color:black;mso-ansi-language:VI;mso-bidi-font-weight:bold">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-bidi-font-weight:bold">ô th</span><span lang="VI" style="color:black;mso-ansi-language:VI;mso-bidi-font-weight:bold">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# <tr style="mso-yfti-irow:1;mso-yfti-lastrow:yes">
# <td style="width:19.9%;border:solid black 1.0pt;border-top:none;
#   mso-border-top-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="19%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">z(mm)</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:30.1%;border-top:none;border-left:none;
#   border-bottom:solid black 1.0pt;border-right:solid black 1.0pt;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="30%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">90</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:27.78%;border-top:none;border-left:none;
#   border-bottom:solid black 1.0pt;border-right:solid black 1.0pt;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="27%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">62,5</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:22.22%;border-top:none;border-left:none;
#   border-bottom:solid black 1.0pt;border-right:solid black 1.0pt;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="22%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">50</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# </table> /TABLE>>
#
#
# <<IMAGE: image1352.jpg /IMAGE>>
#
# <<TABLE: <table border="0" cellpadding="0" cellspacing="0" class="MsoNormalTable" style="width:100.0%;border-collapse:collapse;mso-padding-alt:0cm 0cm 0cm 0cm" width="100%">
# <tr style="mso-yfti-irow:0;mso-yfti-firstrow:yes">
# <td style="width:19.9%;border:solid black 1.0pt;mso-border-alt:
#   solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" width="19%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">Lo</span><span lang="VI" style="color:black;mso-ansi-language:VI;mso-bidi-font-weight:bold">ại
#   đường</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:30.1%;border:solid black 1.0pt;border-left:none;
#   mso-border-left-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="30%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">Đư</span><span lang="VI" style="color:black;mso-ansi-language:VI;mso-bidi-font-weight:bold">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-bidi-font-weight:bold">ôi
#   ngoài đô th</span><span lang="VI" style="color:black;mso-ansi-language:VI;
#   mso-bidi-font-weight:bold">ị</span><span lang="EN" style="mso-ansi-language:
#   EN"><o:p></o:p></span></p>
# </td>
# <td style="width:27.78%;border:solid black 1.0pt;border-left:
#   none;mso-border-left-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="27%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">Đư</span><span lang="VI" style="color:black;mso-ansi-language:VI;mso-bidi-font-weight:bold">ờng
#   th</span><span lang="EN-US" style="color:black;mso-bidi-font-weight:bold">ông
#   thư</span><span lang="VI" style="color:black;mso-ansi-language:VI;mso-bidi-font-weight:
#   bold">ờng</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:22.22%;border:solid black 1.0pt;border-left:
#   none;mso-border-left-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="22%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">Đư</span><span lang="VI" style="color:black;mso-ansi-language:VI;mso-bidi-font-weight:bold">ờng
#   đ</span><span lang="EN-US" style="color:black;mso-bidi-font-weight:bold">ô th</span><span lang="VI" style="color:black;mso-ansi-language:VI;mso-bidi-font-weight:bold">ị</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# <tr style="mso-yfti-irow:1;mso-yfti-lastrow:yes">
# <td style="width:19.9%;border:solid black 1.0pt;border-top:none;
#   mso-border-top-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="19%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">z(mm)</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:30.1%;border-top:none;border-left:none;
#   border-bottom:solid black 1.0pt;border-right:solid black 1.0pt;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="30%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">90</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:27.78%;border-top:none;border-left:none;
#   border-bottom:solid black 1.0pt;border-right:solid black 1.0pt;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="27%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">62,5</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# <td style="width:22.22%;border-top:none;border-left:none;
#   border-bottom:solid black 1.0pt;border-right:solid black 1.0pt;mso-border-top-alt:
#   solid black .5pt;mso-border-left-alt:solid black .5pt;mso-border-alt:solid black .5pt;
#   background:white;padding:0cm 0cm 0cm 0cm" width="22%">
# <p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
#   mso-pagination:none;mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN;mso-bidi-font-weight:bold">50</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
# </td>
# </tr>
# </table> /TABLE>>

# %%
import re
from bs4 import BeautifulSoup

def convert_text_to_markdown(text):
    """
    Chuyển đổi một chuỗi văn bản có cấu trúc cụ thể sang định dạng Markdown.

    Hàm này xử lý các tiêu đề, danh sách, in đậm, hình ảnh và bảng HTML được nhúng.

    Args:
        text: Chuỗi văn bản đầu vào cần chuyển đổi.

    Returns:
        Một chuỗi đã được định dạng Markdown.
    """
    lines = text.split('\n')
    markdown_lines = []
    i = 0
    while i < len(lines):
        line = lines[i].strip()

        # Bỏ qua các dòng trống
        if not line:
            i += 1
            continue

        # Xử lý tiêu đề chính (ví dụ: G1.1. Nhóm...)
        if re.match(r'^G\d+\.\d+\.\s.*', line):
            markdown_lines.append(f"# {line}\n---")
            i += 1
            continue

        # Xử lý tiêu đề phụ (ví dụ: a. Vạch 1.1:)
        if re.match(r'^[a-z]\.\s.*', line):
            # Xóa dấu hai chấm ở cuối nếu có để tiêu đề gọn gàng hơn
            if line.endswith(':'):
                line = line[:-1]
            markdown_lines.append(f"## {line}")
            i += 1
            continue

        keywords = ['Ý nghĩa sử dụng:', 'Quy cách:', 'Minh họa:', 'Lưu ý:', 'Ghi chú:', 'Qui cách:']
        flag = False
        for keyword in keywords:
            if line.startswith(keyword):
                flag = True
                markdown_lines.append(f"**{keyword}** {line[len(keyword):].strip()}")
                i += 1
                break
        if flag:
            continue

        # Xử lý danh sách
        if line.startswith('-') or line.startswith('+') or line.startswith('*'):
            markdown_lines.append(f"* {line[1:].strip()}")
            i += 1
            continue

        # Xử lý hình ảnh (ví dụ: <<IMAGE: image498.jpg /IMAGE>>)
        if line.startswith('<<IMAGE:'):
            match = re.search(r'<<IMAGE:\s*(.*?)\s*/IMAGE>>', line)
            if match:
                image_filename = match.group(1)
                # Chú thích hình ảnh thường ở dòng tiếp theo
                caption = ""
                # if i + 1 < len(lines) and lines[i+1].strip().startswith("Hình G."):
                #     caption = lines[i+1].strip()
                #     i += 1 # Bỏ qua dòng chú thích đã xử lý
                markdown_lines.append(f"![{caption}]({image_filename})")
            i += 1
            continue

        # Xử lý bảng HTML
        if line.startswith('<<TABLE:'):
            table_html_content = ""
            # Trích xuất nội dung HTML của bảng
            while i < len(lines) and ' /TABLE>>' not in lines[i]:
                table_html_content += lines[i].replace('<<TABLE:', '') + "\n"
                i += 1
            table_html_content += lines[i].replace(' /TABLE>>', '') # Thêm dòng cuối cùng

            # Sử dụng BeautifulSoup để phân tích HTML
            soup = BeautifulSoup(table_html_content, 'html.parser')
            table = soup.find('table')
            if table:
                headers = [header.get_text(strip=True) for header in table.find_all('td')[:4]] # Giả sử 4 cột đầu tiên là header

                # Tạo hàng tiêu đề Markdown
                markdown_lines.append(f"| {' | '.join(headers)} |")
                markdown_lines.append(f"|{':---:|' * len(headers)}")

                # Xử lý các hàng dữ liệu
                rows = table.find_all('tr')[1:] # Bỏ qua hàng tiêu đề trong HTML
                for row in rows:
                    cols = [col.get_text(strip=True) for col in row.find_all('td')]
                    markdown_lines.append(f"| {' | '.join(cols)} |")

            i += 1
            continue

        # Xử lý các dòng văn bản thông thường
        markdown_lines.append(line)
        i += 1

    return '\n'.join(markdown_lines)

# %%
processed_text = convert_text_to_markdown(txt)
print(processed_text)
# Out:
# Biển số I.401: Bắt đầu đường ưu tiên
# ![](image1132.jpg)
# Biển số I.402: Hết đoạn đường ưu tiên
# ![](image1134.jpg)
# Biển số I.405a: Đường cụt
# ![](image1136.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.405b: Đường cụt
# ![](image1138.jpg)
# Biển số I.405c: Đường cụt
# ![](image1140.jpg)
# Biển số I.406: Được ưu tiên qua đường hẹp
# ![](image1142.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.407a: Đường một chiều
# ![](image1144.jpg)
# Biển số I.407b: Đường một chiều
# ![](image1146.jpg)
# Biển số I.407c: Đường một chiều
# ![](image1148.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.408: Nơi đỗ xe
# ![](image1150.jpg)
# Biển số I.408a: Nơi đỗ xe một phần trên hè phố
# ![](image1152.jpg)
# Biển số I.409: Chỗ quay xe
# ![](image1154.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.410: Khu vực quay xe
# ![](image1156.jpg)
# Biển số I.413a: Đường có làn đường dành cho ôtô khách
# ![](image1158.jpg)
# Biển số I.413b: Rẽ ra đường có làn đường dành cho ôtô khách
# ![](image1160.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.413c: Rẽ ra đường có làn đường dành cho ôtô khách
# ![](image1162.jpg)
# Biển số I.414a: Chỉ hướng đường
# ![](image1164.jpg)
# Biển số I.414b: Chỉ hướng đường
# ![](image1166.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.414c: Chỉ hướng đường
# ![](image1168.jpg)
# Biển số I.414d: Chỉ hướng đường
# ![](image1170.jpg)
# Biển số I.415: Mũi tên chỉ hướng đi
# ![](image1172.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.416: Đường tránh
# ![](image1174.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 140 | 105 | 70 |
# Biển số I.417a: Chỉ hướng đường phải đi cho từng loại xe
# ![](image1176.jpg)
# Biển số I.417b: Chỉ hướng đường phải đi cho từng loại xe
# ![](image1178.jpg)
# Biển số I.417c: Chỉ hướng đường phải đi cho từng loại xe
# ![](image1180.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.418: Lối đi ở những vị trí cấm rẽ
# ![](image1182.jpg)
# Biển số I.419a: Chỉ dẫn địa giới
# ![](image1184.jpg)
# Biển số I.419b: Chỉ dẫn địa giới trên tuyến đường đối ngoại
# ![](image1186.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.422a: Di tích lịch sử
# ![](image1188.jpg)
# Biển số I.422b: Di tích lịch sử
# ![](image1190.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.423a: Vị trí người đi bộ sang ngang
# ![](image1192.jpg)
# Biển số I.423b: Vị trí người đi bộ sang ngang
# ![](image1194.jpg)
# Biển số I.423c: Điểm bắt đầu đường đi bộ
# ![](image1196.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.424a: Cầu vượt qua đường cho người đi bộ
# ![](image1198.jpg)
# Biển số I.424b: Cầu vượt qua đường cho người đi bộ
# ![](image1200.jpg)
# Biển số I.424c: Hầm chui qua đường cho người đi bộ
# ![](image1202.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.424d: Hầm chui qua đường cho người đi bộ
# ![](image1204.jpg)
# Biển số I.425: Bệnh viện
# ![](image1206.jpg)
# ![](image1208.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.427a: Trạm sửa chữa
# ![](image1210.jpg)
# Biển số I.427b: Công trình kiểm soát tải trọng xe
# ![](image1212.jpg)
# Biển số I.428 (a,b,c): Cửa hàng xăng dầu; Trạm nạp điện; Cửa hàng xăng dầu và Trạm nạp điện (biểu tượng thay đổi theo loại biển tương ứng)
# ![](image1214.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.429: Nơi rửa xe
# ![](image1216.jpg)
# Biển số I.430: Điện thoại
# ![](image1218.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.431: Trạm dừng nghỉ
# ![](image1220.jpg)
# Biển số I.432: Khách sạn
# ![](image1222.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.433a: Nơi nghỉ mát
# ![](image1224.jpg)
# Biển số I.433b: Báo hiệu nơi cắm trại, nhà nghỉ lưu động
# ![](image1226.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.433c: Báo hiệu nơi cắm trại, nhà nghỉ lưu động
# ![](image1228.jpg)
# Biển số I.433d: Báo hiệu nơi cắm trại, nhà nghỉ lưu động
# ![](image1230.jpg)
# Biển số I.433e: Báo hiệu nhà trọ
# ![](image1232.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.434a: Bến xe buýt
# ![](image1234.jpg)
# Biển số I.434b: Bến xe tải
# ![](image1236.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.435: Bến xe điện
# ![](image1238.jpg)
# Biển số I.436: Trạm cảnh sát giao thông
# ![](image1240.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.437: Đường cao tốc
# ![](image1242.jpg)
# Biển số I.439: Tên cầu
# ![](image1244.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.440: Đường đang thi công
# ![](image1246.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 78 | 56,25 | 37,5 |
# Biển số I.441a: Báo hiệu phía trước có công trình thi công
# ![](image1248.jpg)
# Biển số I.441b: Báo hiệu phía trước có công trình thi công
# ![](image1250.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.441c: Báo hiệu phía trước có công trình thi công
# ![](image1252.jpg)
# Biển số I.442: Chợ
# ![](image1254.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.443: Xe kéo moóc
# ![](image1256.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.444a: Biển báo chỉ dẫn địa điểm
# ![](image1258.jpg)
# Biển số I.444b: Biển báo chỉ dẫn địa điểm
# ![](image1260.jpg)
# Biển số I.444c: Biển báo chỉ dẫn địa điểm
# ![](image1262.jpg)
# ![](image1264.jpg)
# Biển số I.444d: Biển báo chỉ dẫn địa điểm
# ![](image1266.jpg)
# Biển số I.444e: Biển báo chỉ dẫn địa điểm
# ![](image1268.jpg)
# Biển số I.444f: Biển báo chỉ dẫn địa điểm
# ![](image1270.jpg)
# Biển số I.444g: Biển báo chỉ dẫn địa điểm
# ![](image1272.jpg)
# Biển số I.444h: Biển báo chỉ dẫn địa điểm
# ![](image1274.jpg)
# Biển số I.444l: Biển báo chỉ dẫn địa điểm
# ![](image1276.jpg)
# Biển số L444j: Biển báo chỉ dẫn địa điểm
# ![](image1278.jpg)
# Biển số L444k: Biển báo chỉ dẫn địa điểm
# ![](image1280.jpg)
# Biển số L444l: Biển báo chỉ dẫn địa điểm
# ![](image1282.jpg)
# | Loại
#   đường | Đường
#   đôi ngoài
#   đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 60 | 80 | 40 |
# Biển số L444m: Biển báo chỉ dẫn địa điểm
# ![](image1284.jpg)
# Biển số I.445a: Biển báo mô tả tình trạng đường
# ![](image1286.jpg)
# Biển số I.445b: Biển báo mô tả tình trạng đường
# ![](image1288.jpg)
# ![](image1290.jpg)
# Biển số I.445c: Biển báo mô tả tình trạng đường
# ![](image1292.jpg)
# Biển số I.445d: Biển báo mô tả tình trạng đường
# ![](image1294.jpg)
# Biển số I.445e: Biển báo mô tả tình trạng đường
# ![](image1296.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 80 | 60 | 40 |
# Biển số I.445f: Biển báo mô tả tình trạng đường
# ![](image1298.jpg)
# Biển số I.445g: Biển báo mô tả tình trạng đường
# ![](image1300.jpg)
# Biển số I.445h: Biển báo mô tả tình trạng đường
# ![](image1302.jpg)
# ![](image1304.jpg)
# Biển số I.446: Nơi để xe dành cho người khuyết tật
# ![](image1306.jpg)
# Biển số I.1447a: Biển báo cầu vượt liên thông
# ![](image1308.jpg)
# Biển số I.1447b: Biển báo cầu vượt liên thông
# ![](image1310.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.447c: Biển báo cầu vượt liên thông
# ![](image1312.jpg)
# Biển số I.447d: Biển báo cầu vượt liên thông
# ![](image1314.jpg)
# Biển số I.448: Làn đường cứu nạn hay làn thoát xe khẩn cấp
# ![](image1316.jpg)
# | Loại
#   đường | Đường
#   đôi ngoài
#   đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# Biển số I.448: Làn đường cứu nạn hay làn thoát xe khẩn cấp
# ![](image1318.jpg)
# Biển số I.448: Làn đường cứu nạn hay làn thoát xe khẩn cấp
# ![](image1320.jpg)
# Biển số I.449: Biển tên đường
# ![](image1322.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 100 | 75 | 50 |
# ![](image1324.jpg)
# ![](image1326.jpg)
# ![](image1328.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 90 | 62,5 | 50 |
# ![](image1330.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 90 | 62,5 | 50 |
# ![](image1332.jpg)
# | Loại
#   đường | Đường
#   đôi ngoài đô thị | Đường
#   thông thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 90 | 62,5 | 50 |
# ![](image1334.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 90 | 62,5 | 50 |
# ![](image1336.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 90 | 62,5 | 50 |
# ![](image1338.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 90 | 62,5 | 50 |
# ![](image1340.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 90 | 62,5 | 50 |
# ![](image1342.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 90 | 62,5 | 50 |
# ![](image1344.jpg)
# ![](image1346.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 90 | 62,5 | 50 |
# ![](image1348.jpg)
# ![](image1350.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 90 | 62,5 | 50 |
# ![](image1352.jpg)
# | Loại
#   đường | Đường
#   đôi
#   ngoài đô thị | Đường
#   thông
#   thường | Đường
#   đô thị |
# |:---:|:---:|:---:|:---:|
# | z(mm) | 90 | 62,5 | 50 |

# %%
html_table = """
<table border="0" cellpadding="0" cellspacing="0" class="MsoNormalTable" style="width:100.0%;border-collapse:collapse;mso-padding-alt:0cm 0cm 0cm 0cm" width="100%">
<tr style="mso-yfti-irow:0;mso-yfti-firstrow:yes">
<td style="width:18.48%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="18%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">T</span><span lang="VI" style="color:black;mso-ansi-language:VI">ốc độ hạn chế lớn nhất</span><span lang="VI" style="color:black"> </span><span lang="VI" style="color:black;
  mso-ansi-language:VI">hoặc tốc độ V<sub>85</sub> (km/h)</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:32.66%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="32%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">T</span><span lang="VI" style="color:black;mso-ansi-language:VI">ầm nh</span><span lang="EN-US" style="color:black">ìn vư</span><span lang="VI" style="color:black;mso-ansi-language:
  VI">ợt xe tối thiểu (m) (chỉ d</span><span lang="EN-US" style="color:black">ùng
  đ</span><span lang="VI" style="color:black;mso-ansi-language:VI">ể x</span><span lang="EN-US" style="color:black">ác đ</span><span lang="VI" style="color:black;
  mso-ansi-language:VI">ịnh v</span><span lang="EN-US" style="color:black">ùng c</span><span lang="VI" style="color:black;mso-ansi-language:VI">ấm vượt)</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:21.02%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="21%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">T</span><span lang="VI" style="color:black;mso-ansi-language:VI">ốc độ hạn chế</span><span lang="VI" style="color:black"> </span><span lang="VI" style="color:black;mso-ansi-language:
  VI">lớn nhất hoặc tốc độ V<sub>85</sub> (km/h)</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:27.84%;border:solid black 1.0pt;
  border-bottom:none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:
  solid black .5pt;mso-border-right-alt:solid black .5pt;background:white;
  padding:0cm 0cm 0cm 0cm" valign="top" width="27%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">T</span><span lang="VI" style="color:black;mso-ansi-language:VI">ầm nh</span><span lang="EN-US" style="color:black">ìn vư</span><span lang="VI" style="color:black;mso-ansi-language:
  VI">ợt xe tối thiểu (m)</span><span lang="VI" style="color:black"> </span><span lang="VI" style="color:black;mso-ansi-language:VI">(chỉ d</span><span lang="EN-US" style="color:black">ùng đ</span><span lang="VI" style="color:black;
  mso-ansi-language:VI">ể x</span><span lang="EN-US" style="color:black">ác đ</span><span lang="VI" style="color:black;mso-ansi-language:VI">ịnh</span><span lang="VI" style="color:black"> </span><span lang="VI" style="color:black;mso-ansi-language:
  VI">v</span><span lang="EN-US" style="color:black">ùng c</span><span lang="VI" style="color:black;mso-ansi-language:VI">ấm vượt)</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
</tr>
<tr style="mso-yfti-irow:1">
<td style="width:18.48%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="18%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">30</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:32.66%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="32%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">120</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:21.02%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="21%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">80</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:27.84%;border:solid black 1.0pt;
  border-bottom:none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:
  solid black .5pt;mso-border-right-alt:solid black .5pt;background:white;
  padding:0cm 0cm 0cm 0cm" valign="top" width="27%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">245</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
</tr>
<tr style="mso-yfti-irow:2">
<td style="width:18.48%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="18%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">40</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:32.66%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="32%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">140</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:21.02%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="21%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">90</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:27.84%;border:solid black 1.0pt;
  border-bottom:none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:
  solid black .5pt;mso-border-right-alt:solid black .5pt;background:white;
  padding:0cm 0cm 0cm 0cm" valign="top" width="27%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">280</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
</tr>
<tr style="mso-yfti-irow:3">
<td style="width:18.48%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="18%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">50</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:32.66%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="32%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">160</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:21.02%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="21%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">100</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:27.84%;border:solid black 1.0pt;
  border-bottom:none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:
  solid black .5pt;mso-border-right-alt:solid black .5pt;background:white;
  padding:0cm 0cm 0cm 0cm" valign="top" width="27%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">320</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
</tr>
<tr style="mso-yfti-irow:4">
<td style="width:18.48%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="18%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">60</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:32.66%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="32%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">180</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:21.02%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="21%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">110</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:27.84%;border:solid black 1.0pt;
  border-bottom:none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:
  solid black .5pt;mso-border-right-alt:solid black .5pt;background:white;
  padding:0cm 0cm 0cm 0cm" valign="top" width="27%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">355</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
</tr>
<tr style="mso-yfti-irow:5;mso-yfti-lastrow:yes">
<td style="width:18.48%;border:solid black 1.0pt;
  border-right:none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:
  solid black .5pt;mso-border-bottom-alt:solid black .5pt;background:white;
  padding:0cm 0cm 0cm 0cm" valign="top" width="18%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">70</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:32.66%;border:solid black 1.0pt;
  border-right:none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:
  solid black .5pt;mso-border-bottom-alt:solid black .5pt;background:white;
  padding:0cm 0cm 0cm 0cm" valign="top" width="32%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">210</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:21.02%;border:solid black 1.0pt;
  border-right:none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:
  solid black .5pt;mso-border-bottom-alt:solid black .5pt;background:white;
  padding:0cm 0cm 0cm 0cm" valign="top" width="21%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">120</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:27.84%;border:solid black 1.0pt;
  mso-border-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="27%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">395</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
</tr>
</table>
"""

# %%
from bs4 import BeautifulSoup
import re

def html_table_to_markdown(html_content):
    """
    Convert HTML table to Markdown format
    """
    # Parse the HTML
    soup = BeautifulSoup(html_content, 'html.parser')

    # Find the table
    table = soup.find('table')
    if not table:
        return "No table found in the HTML content"

    # Extract all rows
    rows = table.find_all('tr')

    markdown_rows = []

    for i, row in enumerate(rows):
        # Get all cells (td or th)
        cells = row.find_all(['td', 'th'])

        # Extract text from each cell and clean it up
        cell_texts = []
        for cell in cells:
            # Get text and clean up whitespace
            text = cell.get_text(strip=True)
            # Remove extra whitespace and line breaks
            text = re.sub(r'\s+', ' ', text)
            cell_texts.append(text)

        # Create markdown row
        if cell_texts:  # Only add non-empty rows
            markdown_row = '| ' + ' | '.join(cell_texts) + ' |'
            markdown_rows.append(markdown_row)

            # Add separator after header row (first row)
            if i == 0:
                separator = '|' + '---|' * len(cell_texts)
                markdown_rows.append(separator)

    return '\n'.join(markdown_rows)

def clean_html_content(html_content):
    """
    Clean up HTML content by removing MS Word specific tags and formatting
    """
    # Remove MS Word specific attributes and tags
    html_content = re.sub(r'style="[^"]*"', '', html_content)
    html_content = re.sub(r'class="[^"]*"', '', html_content)
    html_content = re.sub(r'mso-[^:]*:[^;]*;?', '', html_content)
    html_content = re.sub(r'<o:p[^>]*>.*?</o:p>', '', html_content)
    html_content = re.sub(r'lang="[^"]*"', '', html_content)
    html_content = re.sub(r'valign="[^"]*"', '', html_content)
    html_content = re.sub(r'width="[^"]*"', '', html_content)
    html_content = re.sub(r'align="[^"]*"', '', html_content)

    return html_content

# %%
# clean_html_table = clean_html_content(html_table)
markdown_table = html_table_to_markdown(html_table)
print(markdown_table)
# Out:
# | Tốc độ hạn chế lớn nhấthoặc tốc độ V85(km/h) | Tầm nhìn vượt xe tối thiểu (m) (chỉ dùng để xác định vùng cấm vượt) | Tốc độ hạn chếlớn nhất hoặc tốc độ V85(km/h) | Tầm nhìn vượt xe tối thiểu (m)(chỉ dùng để xác địnhvùng cấm vượt) |
# |---|---|---|---|
# | 30 | 120 | 80 | 245 |
# | 40 | 140 | 90 | 280 |
# | 50 | 160 | 100 | 320 |
# | 60 | 180 | 110 | 355 |
# | 70 | 210 | 120 | 395 |

# %%
from bs4 import BeautifulSoup
import re

def html_table_to_markdown(html_content):
    """
    Convert HTML table to Markdown format
    """
    # Parse the HTML
    soup = BeautifulSoup(html_content, 'html.parser')

    # Find the table
    table = soup.find('table')
    if not table:
        return "No table found in the HTML content"

    # Extract all rows
    rows = table.find_all('tr')

    markdown_rows = []

    for i, row in enumerate(rows):
        # Get all cells (td or th)
        cells = row.find_all(['td', 'th'])

        # Extract text from each cell and clean it up
        cell_texts = []
        for cell in cells:
            # Get text and clean up whitespace
            text = cell.get_text(strip=True)
            # Remove extra whitespace and line breaks
            text = re.sub(r'\s+', ' ', text)
            cell_texts.append(text)

        # Create markdown row
        if cell_texts:  # Only add non-empty rows
            markdown_row = '| ' + ' | '.join(cell_texts) + ' |'
            markdown_rows.append(markdown_row)

            # Add separator after header row (first row)
            if i == 0:
                separator = '|' + '---|' * len(cell_texts)
                markdown_rows.append(separator)

    return '\n'.join(markdown_rows)

def clean_html_content(html_content):
    """
    Clean up HTML content by removing MS Word specific tags and formatting
    """
    # Remove MS Word specific attributes and tags
    html_content = re.sub(r'style="[^"]*"', '', html_content)
    html_content = re.sub(r'class="[^"]*"', '', html_content)
    html_content = re.sub(r'mso-[^:]*:[^;]*;?', '', html_content)
    html_content = re.sub(r'<o:p[^>]*>.*?</o:p>', '', html_content)
    html_content = re.sub(r'lang="[^"]*"', '', html_content)
    html_content = re.sub(r'valign="[^"]*"', '', html_content)
    html_content = re.sub(r'width="[^"]*"', '', html_content)
    html_content = re.sub(r'align="[^"]*"', '', html_content)

    return html_content

# Example usage with your HTML content
html_content = '''<table border="0" cellpadding="0" cellspacing="0" class="MsoNormalTable" style="width:100.0%;border-collapse:collapse;mso-padding-alt:0cm 0cm 0cm 0cm" width="100%">
<tr style="mso-yfti-irow:0;mso-yfti-firstrow:yes">
<td style="width:18.48%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="18%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">T</span><span lang="VI" style="color:black;mso-ansi-language:VI">ốc độ hạn chế lớn nhất</span><span lang="VI" style="color:black"> </span><span lang="VI" style="color:black;
  mso-ansi-language:VI">hoặc tốc độ V<sub>85</sub> (km/h)</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:32.66%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="32%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">T</span><span lang="VI" style="color:black;mso-ansi-language:VI">ầm nhìn vượt xe tối thiểu (m) (chỉ dùng để xác định vùng cấm vượt)</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:21.02%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="21%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">T</span><span lang="VI" style="color:black;mso-ansi-language:VI">ốc độ hạn chế lớn nhất hoặc tốc độ V<sub>85</sub> (km/h)</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:27.84%;border:solid black 1.0pt;
  border-bottom:none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:
  solid black .5pt;mso-border-right-alt:solid black .5pt;background:white;
  padding:0cm 0cm 0cm 0cm" valign="top" width="27%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">T</span><span lang="VI" style="color:black;mso-ansi-language:VI">ầm nhìn vượt xe tối thiểu (m) (chỉ dùng để xác định vùng cấm vượt)</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
</tr>
<tr style="mso-yfti-irow:1">
<td style="width:18.48%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="18%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">30</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:32.66%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="32%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">120</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:21.02%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="21%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">80</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:27.84%;border:solid black 1.0pt;
  border-bottom:none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:
  solid black .5pt;mso-border-right-alt:solid black .5pt;background:white;
  padding:0cm 0cm 0cm 0cm" valign="top" width="27%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">245</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
</tr>
<tr style="mso-yfti-irow:2">
<td style="width:18.48%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="18%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">40</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:32.66%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="32%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">140</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:21.02%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="21%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">90</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:27.84%;border:solid black 1.0pt;
  border-bottom:none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:
  solid black .5pt;mso-border-right-alt:solid black .5pt;background:white;
  padding:0cm 0cm 0cm 0cm" valign="top" width="27%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">280</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
</tr>
<tr style="mso-yfti-irow:3">
<td style="width:18.48%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="18%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">50</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:32.66%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="32%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">160</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:21.02%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="21%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">100</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:27.84%;border:solid black 1.0pt;
  border-bottom:none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:
  solid black .5pt;mso-border-right-alt:solid black .5pt;background:white;
  padding:0cm 0cm 0cm 0cm" valign="top" width="27%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">320</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
</tr>
<tr style="mso-yfti-irow:4">
<td style="width:18.48%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="18%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">60</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:32.66%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="32%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">180</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:21.02%;border-top:solid black 1.0pt;
  border-left:solid black 1.0pt;border-bottom:none;border-right:none;
  mso-border-top-alt:solid black .5pt;mso-border-left-alt:solid black .5pt;
  background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="21%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">110</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:27.84%;border:solid black 1.0pt;
  border-bottom:none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:
  solid black .5pt;mso-border-right-alt:solid black .5pt;background:white;
  padding:0cm 0cm 0cm 0cm" valign="top" width="27%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">355</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
</tr>
<tr style="mso-yfti-irow:5;mso-yfti-lastrow:yes">
<td style="width:18.48%;border:solid black 1.0pt;
  border-right:none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:
  solid black .5pt;mso-border-bottom-alt:solid black .5pt;background:white;
  padding:0cm 0cm 0cm 0cm" valign="top" width="18%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">70</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:32.66%;border:solid black 1.0pt;
  border-right:none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:
  solid black .5pt;mso-border-bottom-alt:solid black .5pt;background:white;
  padding:0cm 0cm 0cm 0cm" valign="top" width="32%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">210</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:21.02%;border:solid black 1.0pt;
  border-right:none;mso-border-top-alt:solid black .5pt;mso-border-left-alt:
  solid black .5pt;mso-border-bottom-alt:solid black .5pt;background:white;
  padding:0cm 0cm 0cm 0cm" valign="top" width="21%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">120</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
<td style="width:27.84%;border:solid black 1.0pt;
  mso-border-alt:solid black .5pt;background:white;padding:0cm 0cm 0cm 0cm" valign="top" width="27%">
<p align="center" class="MsoNormal" style="margin-top:6.0pt;text-align:center;
  mso-layout-grid-align:none;text-autospace:none"><span lang="EN" style="color:black;mso-ansi-language:EN">395</span><span lang="EN" style="mso-ansi-language:EN"><o:p></o:p></span></p>
</td>
</tr>
</table>'''

# Convert to markdown
markdown_table = html_table_to_markdown(html_content)
print("Markdown Table:")
print(markdown_table)

# If you want to read from a file instead:
def convert_html_file_to_markdown(file_path):
    """
    Convert HTML table from a file to markdown
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            html_content = file.read()
        return html_table_to_markdown(html_content)
    except FileNotFoundError:
        return f"File {file_path} not found"
    except Exception as e:
        return f"Error reading file: {str(e)}"

# Example usage:
# markdown_result = convert_html_file_to_markdown('your_table.html')
# print(markdown_result)
# Out:
# Markdown Table:
# | Tốc độ hạn chế lớn nhấthoặc tốc độ V85(km/h) | Tầm nhìn vượt xe tối thiểu (m) (chỉ dùng để xác định vùng cấm vượt) | Tốc độ hạn chế lớn nhất hoặc tốc độ V85(km/h) | Tầm nhìn vượt xe tối thiểu (m) (chỉ dùng để xác định vùng cấm vượt) |
# |---|---|---|---|
# | 30 | 120 | 80 | 245 |
# | 40 | 140 | 90 | 280 |
# | 50 | 160 | 100 | 320 |
# | 60 | 180 | 110 | 355 |
# | 70 | 210 | 120 | 395 |
